# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
from google.colab import files
uploaded= files.upload()
# Out:
#      <input type="file" id="files-835c20e3-883b-4ddd-acd6-58119f46449f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-835c20e3-883b-4ddd-acd6-58119f46449f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving rates.csv to rates.csv

# %%
df = pd.read_csv("rates.csv")
df
# Out:
#    area   price
# 0  2300  550000
# 1  3000  565000
# 2  3200  610000
# 3  3700  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price, color="red", marker='+')
plt.xlabel('area(sqr feet)')
plt.ylabel('price(INR)')
plt.plot(df.area, regr.predict(df[['area']]),color="purple")

# %%
regr = linear_model.LinearRegression()
regr.fit(df[['area']],df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regr.predict([[5000]])
# Out:
# array([815819.86143187])

# %%
regr.coef_
# Out:
# array([107.852194])

# %%
regr.intercept_
# Out:
# 276558.8914549654

# %%
from google.colab import files
uploade = files.upload()
# Out:
#      <input type="file" id="files-c1287bcf-d3bb-4ab8-90a4-d9b3ace9ceba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1287bcf-d3bb-4ab8-90a4-d9b3ace9ceba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample_areas.csv to sample_areas.csv

# %%
d = pd.read_csv("sample_areas.csv")
print(d)
# Out:
#       area
# 0     1000
# 1     1234
# 2     1324
# 3     1456
# 4     1777
# 5     1889
# 6     2050
# 7     2202
# 8     2291
# 9     2344
# 10    2433
# 11    2666
# 12    2777
# 13    3000

# %%
p= regr.predict(d)

# %%
d["prices"] = p
print(d)
# Out:
#       area         prices
# 0     1000  384411.085450
# 1     1234  409648.498845
# 2     1324  419355.196305
# 3     1456  433591.685912
# 4     1777  468212.240185
# 5     1889  480291.685912
# 6     2050  497655.889145
# 7     2202  514049.422633
# 8     2291  523648.267898
# 9     2344  529364.434180
# 10    2433  538963.279446
# 11    2666  564092.840647
# 12    2777  576064.434180
# 13    3000  600115.473441

# %%
d.to_csv("pred_model.csv")
